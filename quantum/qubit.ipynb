# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, BasicAer, IBMQ
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.extensions import Initialize
from qiskit_textbook.tools import random_state, array_to_latex
import math

# %%
psi = random_state(1)
array_to_latex(psi, pretext="|\\psi\\rangle =")
plot_bloch_multivector(psi)
# Out:
# $\displaystyle
# |\psi\rangle =\begin{bmatrix}
# -0.2793 + 0.50679i \\
# 0.3153 - 0.75215i
# \end{bmatrix}
# $

# %%
psi
# Out:
# array([-0.27930333+0.50679237j,  0.31530498-0.75215285j])

# %%
psi[0], psi[0].conjugate()
# Out:
# ((-0.27930332502805316+0.5067923716087785j),
#  (-0.27930332502805316-0.5067923716087785j))

# %%
psi[0] * psi[0].conjugate() + psi[1] * psi[1].conjugate()
# Out:
# (1+0j)

# %%
psi[0], psi[1]
# Out:
# ((-0.27930332502805316+0.5067923716087785j),
#  (0.3153049816010116-0.7521528523412041j))

# %%
a = -0.27930332502805316
b = 0.5067923716087785
c = 0.3153049816010116
d = 0.7521528523412041

a ** 2 + b ** 2 + c ** 2 + d ** 2
# Out:
# 1.0

# %%
math.sqrt(0.5) / 3
# Out:
# 0.23570226039551587

# %%
2 * math.sqrt(2/9)
# Out:
# 0.9428090415820634
