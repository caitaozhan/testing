# %% [markdown]
# # Visualize all the Layers in https://github.com/mit-han-lab/torchquantum/blob/master/torchquantum/layers.py

# %%
import torchquantum as tq
from torchquantum.plugins.qiskit_plugin import tq2qiskit
import torchquantum.functional as tqf

# %% [markdown]
# # Random Layer (only RX, RY, RZ, CNOT)

# %%
# np.random.seed(42)
# torch.manual_seed(42)
n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
rlayer = tq.RandomLayer(n_ops=16, wires=list(range(n_qubits)))
circ = tq2qiskit(dev, rlayer)
circ.draw('mpl')

# %% [markdown]
# # Random Layer (all types of gates, some connot be converted to Qiskit)

# %%
n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
rlayer = tq.RandomLayerAllTypes(n_ops=16, wires=list(range(n_qubits)))
circ = tq2qiskit(dev, rlayer)
circ.draw('mpl')

# %% [markdown]
# # Simple Layer

# %%
n_qubits = 3
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.SimpleQLayer(n_wires=n_qubits)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # CX Layer

# %%
n_qubits = 2
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.CXLayer(n_wires=n_qubits)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # CXCXCX Layer

# %%
n_qubits = 3
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.CXCXCXLayer(n_wires=n_qubits)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # SWAPSWAP Layer

# %%
n_qubits = 3
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.SWAPSWAPLayer(n_wires=n_qubits)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Op1QAllLayer

# %%
n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.Op1QAllLayer(op=tq.RZ, n_wires=n_qubits, has_params=True, trainable=True)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Op2QAllLayer

# %%
n_qubits = 3
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.Op2QAllLayer(op=tq.CRZ, n_wires=n_qubits, has_params=True, trainable=True, jump=1, circular=True)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Op2QFit32Layer

# %%
n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.Op2QFit32Layer(op=tq.CNOT, n_wires=n_qubits, has_params=True, trainable=True, jump=1)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # ButterflyLayer

# %%
n_qubits = 6
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.Op2QButterflyLayer(op=tq.CNOT, n_wires=n_qubits, has_params=True, trainable=True)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Op2QDenseLayer

# %%
n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.Op2QDenseLayer(op=tq.CNOT, n_wires=n_qubits, has_params=True, trainable=True)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # U3CU3 Layer

# %%
n_qubits = 4
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.U3CU3Layer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # CU3 Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.CU3Layer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # CXRZSX Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.CXRZSXLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Seth Layer 0

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.SethLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Seth Layer 1

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.SethLayer1(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Seth Layer 2

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.SethLayer2(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # RXX Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.RZZLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Barren Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.BarrenLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Farhi Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.FarhiLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Maxwell Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 2}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.MaxwellLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # RYRYCX Layer

# %%
n_qubits = 2
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.RYRYCXLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # RYRYRYCXCXCX Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.RYRYRYCXCXCXLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # RYRYRY Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.RYRYRYLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # RYRYRYSWAPSWAP Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.RYRYRYSWAPSWAPLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # SWAPSWAP Layer

# %%
n_qubits = 3
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.SWAPSWAPLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # RXYZCX Layer

# %%
n_qubits = 4
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = tq.layers.RXYZCXLayer0(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # MyRXYZCX Layer

# %%
class MyRXYZCX(tq.layers.LayerTemplate0):
    def build_layers(self):
        layers_all = tq.QuantumModuleList()
        for _ in range(self.arch['n_blocks']):
            layers_all.append(tq.Op1QAllLayer(op=tq.RX, n_wires=self.n_wires, has_params=True, trainable=False))
            layers_all.append(tq.Op1QAllLayer(op=tq.RY, n_wires=self.n_wires, has_params=True, trainable=False))
            layers_all.append(tq.Op1QAllLayer(op=tq.RZ, n_wires=self.n_wires, has_params=True, trainable=False))
            layers_all.append(tq.Op2QAllLayer(op=tq.CNOT, n_wires=self.n_wires, jump=1, circular=True))
        return layers_all

# %%
n_qubits = 4
arch = {'n_wires': n_qubits, 'n_blocks': 1, 'n_layers_per_block': 1}
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = MyRXYZCX(arch)
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # The Quantum Layer in https://github.com/mit-han-lab/torchquantum/blob/e928ac9ba3a9d6d2910f7b9889fe1654c9b94506/mnist_example.py#L22

# %%
class QLayer(tq.QuantumModule):
    def __init__(self):
        super().__init__()
        self.n_wires = 4
        self.random_layer = tq.RandomLayer(n_ops=50, wires=list(range(self.n_wires)))

        # gates with trainable parameters
        self.rx0 = tq.RX(has_params=True, trainable=True)
        self.ry0 = tq.RY(has_params=True, trainable=True)
        self.rz0 = tq.RZ(has_params=True, trainable=True)
        self.crx0 = tq.CRX(has_params=True, trainable=True)

    @tq.static_support
    def forward(self, q_device: tq.QuantumDevice):
        """
        1. To convert tq QuantumModule to qiskit or run in the static model, need to:
            (1) add @tq.static_support before the forward
            (2) make sure to add
                static=self.static_mode and
                parent_graph=self.graph
                to all the tqf functions, such as tqf.hadamard below
        """
        self.q_device = q_device

        self.random_layer(self.q_device)

        # some trainable gates (instantiated ahead of time)
        self.rx0(self.q_device, wires=0)
        self.ry0(self.q_device, wires=1)
        self.rz0(self.q_device, wires=3)
        self.crx0(self.q_device, wires=[0, 2])

        # add some more non-parameterized gates (add on-the-fly)
        tqf.hadamard(self.q_device, wires=3, static=self.static_mode, parent_graph=self.graph)
        tqf.sx(self.q_device, wires=2, static=self.static_mode, parent_graph=self.graph)
        tqf.cnot(self.q_device, wires=[3, 0], static=self.static_mode, parent_graph=self.graph)
        

n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
qlayer = QLayer()
circ = tq2qiskit(dev, qlayer)
circ.draw('mpl')

# %% [markdown]
# # Encoder

# %%
n_qubits = 4
dev = tq.QuantumDevice(n_wires=n_qubits)
# rlayer = tq.RandomLayer(n_ops=30, wires=list(range(n_qubits)))
encoder = tq.GeneralEncoder(tq.encoder_op_list_name_dict['4x4_ryzxy'])
circ = tq2qiskit(dev, encoder)
circ.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_22311/397178647.py in <module>
#       3 # rlayer = tq.RandomLayer(n_ops=30, wires=list(range(n_qubits)))
#       4 encoder = tq.GeneralEncoder(tq.encoder_op_list_name_dict['4x4_ryzxy'])
# ----> 5 circ = tq2qiskit(dev, encoder)
#       6 circ.draw('mpl')
#
# ~/Project/torchquantum/torchquantum/plugins/qiskit_plugin.py in tq2qiskit(q_device, m, x, draw, remove_ops, remove_ops_thres)
#     291     # forward to register all modules and parameters
#     292     if x is None:
# --> 293         m.forward(q_device)
#     294     else:
#     295         m.forward(q_device, x)
#
# ~/Project/torchquantum/torchquantum/graph.py in forward_register_graph(*args, **kwargs)
#      23         if args[0].static_mode and args[0].parent_graph is not None:
#      24             args[0].parent_graph.add_op(args[0])
# ...
