# %%
from scipy.ndimage import gaussian_filter
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.zeros(21*21).reshape((21, 21))
a[10][13] = 85
a[10][7] = 83
a = gaussian_filter(a, sigma=1.5)
print('sum', np.sum(a))
print('sum', np.sum(a[2:19, 2:19]))
print('sum', np.sum(a[4:17, 4:17]))
fig, ax = plt.subplots(figsize=(22, 20))
sns.heatmap(a, cmap='gray', annot=True)
# Out:
# sum 168.0
# sum 167.98501086046923
# sum 166.53591026631364
# <AxesSubplot:>

# %%
a = np.zeros(21*21).reshape((21, 21))
a[2][2] = 5
a = gaussian_filter(a, sigma=1.5)
print('sum', np.sum(a))
print('sum', np.sum(a[2:19, 2:19]))
print('sum', np.sum(a[4:17, 4:17]))
fig, ax = plt.subplots(figsize=(22, 20))
sns.heatmap(a, cmap='gray', annot=True)
# Out:
# sum 5.0
# sum 2.0104111726284013
# sum 0.1186575406943039
# <AxesSubplot:>
